# %% [markdown]
# # DeepWave

# %% [markdown]
# ## 1. Loading the necessary libraries

# %%
from glob import glob
import numpy as np
import os
import mne
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Conv1D, BatchNormalization, LeakyReLU, MaxPool1D, GlobalAveragePooling1D, Dense, Dropout, AveragePooling1D
from tensorflow.keras.models import Sequential
from tensorflow.keras.backend import clear_session
from tensorflow.keras.utils import plot_model
from sklearn.model_selection import GroupKFold, LeaveOneGroupOut
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 2. Reading the Data

# %%
healthy_path = glob('Dataset\\train\\Healthy\\*.edf')
mdd_path = glob('Dataset\\train\\MDD\\*.edf')

# %%
exclude = ('EEG 23A-23R', 'EEG 24A-24R', 'Status', 'EEG A2-A1')

# %%
def read_eeg(path):
    raw = mne.io.read_raw_edf(path, preload=True, exclude=exclude)
    raw.set_eeg_reference()
    raw.filter(l_freq=0.5, h_freq=45)
    epoch = mne.make_fixed_length_epochs(raw, duration=5, overlap=1)
    array = epoch.get_data()
    return array

# %%
healthy = [read_eeg(path) for path in healthy_path]
mdd = [read_eeg(path) for path in mdd_path]
# Out:
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset-v1\train\Healthy\6921143_H_S15_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77311  =      0.000 ...   301.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Not setting metadata
# 75 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 75 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset-v1\train\Healthy\6921959_H_S15_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77311  =      0.000 ...   301.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Not setting metadata
# 75 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 75 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset-v1\train\Healthy\H_S10_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 96255  =      0.000 ...   375.996 secs...
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Not setting metadata
# 93 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 93 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset-v1\train\Healthy\H_S10_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Not setting metadata
# 74 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 74 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset-v1\train\Healthy\H_S10_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 154879  =      0.000 ...   604.996 secs...
# EEG channel type selected for re-referencing
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Not setting metadata
# 151 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 151 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset-v1\train\Healthy\H_S11_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Not setting metadata
# 74 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 74 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset-v1\train\Healthy\H_S11_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77311  =      0.000 ...   301.996 secs...
# EEG channel type selected for re-referencing
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Not setting metadata
# 75 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 75 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset-v1\train\Healthy\H_S11_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 154879  =      0.000 ...   604.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Not setting metadata
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# 151 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 151 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset-v1\train\Healthy\H_S12_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Not setting metadata
# 74 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 74 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset-v1\train\Healthy\H_S12_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 154879  =      0.000 ...   604.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Not setting metadata
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# 151 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 151 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset-v1\train\Healthy\H_S13_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Not setting metadata
# 74 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 74 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset-v1\train\Healthy\H_S13_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77567  =      0.000 ...   302.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Not setting metadata
# 75 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 75 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset-v1\train\Healthy\H_S13_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 156159  =      0.000 ...   609.996 secs...
# EEG channel type selected for re-referencing
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Not setting metadata
# 152 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 152 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset-v1\train\Healthy\H_S14_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77311  =      0.000 ...   301.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Not setting metadata
# 75 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 75 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset-v1\train\Healthy\H_S14_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 49663  =      0.000 ...   193.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Not setting metadata
# 48 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 48 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset-v1\train\Healthy\H_S14_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 155391  =      0.000 ...   606.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Not setting metadata
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# 151 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 151 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset-v1\train\Healthy\H_S15_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Not setting metadata
# 74 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 74 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset-v1\train\Healthy\H_S15_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 156159  =      0.000 ...   609.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Not setting metadata
# 152 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 152 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset-v1\train\Healthy\H_S16_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 74751  =      0.000 ...   291.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Not setting metadata
# 72 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 72 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset-v1\train\Healthy\H_S16_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76543  =      0.000 ...   298.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Not setting metadata
# 74 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 74 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset-v1\train\Healthy\H_S16_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 162303  =      0.000 ...   633.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Not setting metadata
# 158 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 158 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset-v1\train\Healthy\H_S17_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 79103  =      0.000 ...   308.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Not setting metadata
# 77 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 77 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset-v1\train\Healthy\H_S17_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77055  =      0.000 ...   300.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Not setting metadata
# 75 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 75 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset-v1\train\Healthy\H_S17_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 154879  =      0.000 ...   604.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Not setting metadata
# 151 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 151 events and 1280 original time points ...
# 0 bad epochs dropped
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset-v1\train\Healthy\H_S18_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77055  =      0.000 ...   300.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Not setting metadata
# 75 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 75 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset-v1\train\Healthy\H_S18_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 155647  =      0.000 ...   607.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Not setting metadata
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# 151 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 151 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset-v1\train\Healthy\H_S19_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Not setting metadata
# 74 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 74 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset-v1\train\Healthy\H_S19_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77055  =      0.000 ...   300.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Not setting metadata
# 75 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 75 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset-v1\train\Healthy\H_S19_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 155647  =      0.000 ...   607.996 secs...
# EEG channel type selected for re-referencing
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Not setting metadata
# 151 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 151 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset-v1\train\Healthy\H_S1_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Not setting metadata
# 74 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 74 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset-v1\train\Healthy\H_S1_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 89855  =      0.000 ...   350.996 secs...
# EEG channel type selected for re-referencing
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 87 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset-v1\train\Healthy\H_S1_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 154879  =      0.000 ...   604.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Not setting metadata
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# 151 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 151 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset-v1\train\Healthy\H_S20_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 78591  =      0.000 ...   306.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Not setting metadata
# 76 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 76 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset-v1\train\Healthy\H_S20_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 81919  =      0.000 ...   319.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Not setting metadata
# 79 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 79 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset-v1\train\Healthy\H_S21_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77055  =      0.000 ...   300.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Not setting metadata
# 75 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 75 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset-v1\train\Healthy\H_S21_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 78079  =      0.000 ...   304.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Not setting metadata
# 76 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 76 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset-v1\train\Healthy\H_S22_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77055  =      0.000 ...   300.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Not setting metadata
# 75 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 75 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset-v1\train\Healthy\H_S22_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76543  =      0.000 ...   298.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Not setting metadata
# 74 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 74 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset-v1\train\Healthy\H_S22_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 154623  =      0.000 ...   603.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Not setting metadata
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# 150 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 150 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset-v1\train\Healthy\H_S23_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77311  =      0.000 ...   301.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Not setting metadata
# 75 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 75 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset-v1\train\Healthy\H_S23_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77311  =      0.000 ...   301.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ...
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Not setting metadata
# 73 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 73 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset\train\MDD\MDD_S44_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 73215  =      0.000 ...   285.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Not setting metadata
# 71 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 71 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset\train\MDD\MDD_S44_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 74751  =      0.000 ...   291.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Not setting metadata
# 72 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 72 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset\train\MDD\MDD_S45_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 71935  =      0.000 ...   280.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Not setting metadata
# 70 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 70 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset\train\MDD\MDD_S45_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 75775  =      0.000 ...   295.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Not setting metadata
# 73 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 73 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset\train\MDD\MDD_S4_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77055  =      0.000 ...   300.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Not setting metadata
# 75 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 75 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset\train\MDD\MDD_S5_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77311  =      0.000 ...   301.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Not setting metadata
# 75 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 75 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset\train\MDD\MDD_S5_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77311  =      0.000 ...   301.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Not setting metadata
# 75 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 75 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset\train\MDD\MDD_S6_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77311  =      0.000 ...   301.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Not setting metadata
# 75 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 75 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset\train\MDD\MDD_S6_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77055  =      0.000 ...   300.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Not setting metadata
# 75 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 75 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset\train\MDD\MDD_S7_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Not setting metadata
# 74 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 74 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset\train\MDD\MDD_S7_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 162815  =      0.000 ...   635.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Not setting metadata
# 158 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 158 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset\train\MDD\MDD_S9_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Not setting metadata
# 74 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 74 events and 1280 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset\train\MDD\MDD_S9_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Not setting metadata
# 74 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 74 events and 1280 original time points ...
# 0 bad epochs dropped
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s

# %%
raw = mne.io.read_raw_edf(mdd_path[1], preload=True, exclude=exclude)
raw.info
# Out:
# Extracting EDF parameters from C:\MachineLearning\2023\10.EEGPaper\Dataset\train\MDD\MDD_S10_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# <Info | 7 non-empty values
#  bads: []
#  ch_names: EEG Fp1-LE, EEG F3-LE, EEG C3-LE, EEG P3-LE, EEG O1-LE, EEG ...
#  chs: 20 EEG
#  custom_ref_applied: False
#  highpass: 0.5 Hz
#  lowpass: 80.0 Hz
#  meas_date: 2013-06-11 11:35:22 UTC
#  nchan: 20
#  projs: []
#  sfreq: 256.0 Hz
# >

# %%
raw.plot()
# Out:
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
healthy_labels = [len(arr)*[0] for arr in healthy]
mdd_labels = [len(arr)*[1] for arr in mdd]

# %%
print(len(healthy_labels), len(mdd_labels))
# Out:
# 69 72

# %%
eeg = healthy + mdd
labels = healthy_labels + mdd_labels

# %%
groups = [[i]*len(j) for i, j in enumerate(eeg)]

# %%
eeg_array = np.vstack(eeg)
label_array = np.hstack(labels)
group_array = np.hstack(groups)
eeg_array = np.moveaxis(eeg_array, 1, 2)

# %%
print(eeg_array.shape, label_array.shape, group_array.shape)
# Out:
# (12228, 1280, 19) (12228,) (12228,)

# %%
model = Sequential()
model.add(Conv1D(filters=5, kernel_size=3, strides=1, input_shape=(1280, 19)))#1
model.add(BatchNormalization())
model.add(LeakyReLU())
model.add(MaxPool1D(pool_size=2, strides=2))#2
model.add(Conv1D(filters=5, kernel_size=3, strides=1))#3
model.add(LeakyReLU())
model.add(MaxPool1D(pool_size=2, strides=2))#4
model.add(Dropout(0.5))
model.add(Conv1D(filters=5, kernel_size=3, strides=1))#5
model.add(LeakyReLU())
model.add(AveragePooling1D(pool_size=2, strides=2))#6
model.add(Dropout(0.5))
model.add(Conv1D(filters=5, kernel_size=3, strides=1))#7
model.add(LeakyReLU())
model.add(AveragePooling1D(pool_size=2, strides=2))#8
model.add(Conv1D(filters=5, kernel_size=3, strides=1))#9
model.add(LeakyReLU())
model.add(GlobalAveragePooling1D())#10
model.add(Dense(1, activation='sigmoid'))#11
model.compile('adam', loss='binary_crossentropy', metrics=['accuracy'])

model_name = 'DeepWave'
plot_model(model, to_file=f"Images/{model_name}_architecture.png", show_shapes=True, show_layer_names=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 1278, 5)           290
#
#  batch_normalization (BatchN  (None, 1278, 5)          20
#  ormalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 1278, 5)           0
#
#  max_pooling1d (MaxPooling1D  (None, 639, 5)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 637, 5)            80
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 637, 5)            0
#
#  max_pooling1d_1 (MaxPooling  (None, 318, 5)           0
#  1D)
#
#  dropout (Dropout)           (None, 318, 5)            0
#
#  conv1d_2 (Conv1D)           (None, 316, 5)            80
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 316, 5)            0
#
#  average_pooling1d (AverageP  (None, 158, 5)           0
#  ooling1D)
#
#  dropout_1 (Dropout)         (None, 158, 5)            0
#
#  conv1d_3 (Conv1D)           (None, 156, 5)            80
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 156, 5)            0
#
#  average_pooling1d_1 (Averag  (None, 78, 5)            0
#  ePooling1D)
#
#  conv1d_4 (Conv1D)           (None, 76, 5)             80
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 76, 5)             0
#
#  global_average_pooling1d (G  (None, 5)                0
#  lobalAveragePooling1D)
#
#  dense (Dense)               (None, 1)                 6
#
# =================================================================
# Total params: 636
# Trainable params: 626
# Non-trainable params: 10
# _________________________________________________________________

# %%
gkf = GroupKFold()

# %%
accuracy=[]
for train_index, val_index in gkf.split(eeg_array, label_array, groups=group_array):
    train_features, train_labels = eeg_array[train_index], label_array[train_index]
    val_features,val_labels = eeg_array[val_index], label_array[val_index]
    scaler=StandardScaler()
    train_features = scaler.fit_transform(train_features.reshape(-1, train_features.shape[-1])).reshape(train_features.shape)
    val_features = scaler.transform(val_features.reshape(-1, val_features.shape[-1])).reshape(val_features.shape)
    model.fit(train_features, train_labels, epochs=50, batch_size=128, validation_data=(val_features, val_labels))
    accuracy.append(model.evaluate(val_features, val_labels)[1])
# Out:
# Epoch 1/50
# 77/77 [==============================] - 6s 18ms/step - loss: 0.6009 - accuracy: 0.5657 - val_loss: 0.5942 - val_accuracy: 0.5563
# Epoch 2/50
# 77/77 [==============================] - 1s 13ms/step - loss: 0.4504 - accuracy: 0.7442 - val_loss: 0.5173 - val_accuracy: 0.7249
# Epoch 3/50
# 77/77 [==============================] - 1s 12ms/step - loss: 0
50
# 77/77 [==============================] - 1s 12ms/step - loss: 0.1560 - accuracy: 0.9358 - val_loss: 0.7468 - val_accuracy: 0.7640
# Epoch 29/50
# 77/77 [==============================] - 1s 12ms/step - loss: 0.1359 - accuracy: 0.9465 - val_loss: 0.6708 - val_accuracy: 0.8521
# Epoch 30/50
# 77/77 [==============================] - 1s 12ms/step - loss: 0.1308 - accuracy: 0.9477 - val_loss: 0.7250 - val_accuracy: 0.8062
# Epoch 31/50
# 77/77 [==============================] - 1s 12ms/step - loss: 0.1245 - accuracy: 0.9505 - val_loss: 0.6602 - val_accuracy: 0.8296
# Epoch 32/50
# 77/77 [==============================] - 1s 12ms/step - loss: 0.1314 - accuracy: 0.9512 - val_loss: 0.6940 - val_accuracy: 0.8156
# Epoch 33/50
# 77/77 [==============================] - 1s 17ms/step - loss: 0.1303 - accuracy: 0.9490 - val_loss: 0.7749 - val_accuracy: 0.7763
# Epoch 34/50
# 77/77 [==============================] - 1s 16ms/step - loss: 0.1184 - accuracy: 0.9553 - val_loss: 0.7774 - val_accuracy: 0.8029
# Epoch 35/50
# 77/77 [==============================] - 1s 19ms/step - loss: 0.1141 - accuracy: 0.9568 - val_loss: 0.5384 - val_accuracy: 0.9000
# Epoch 36/50
# 77/77 [==============================] - 1s 12ms/step - loss: 0.1177 - accuracy: 0.9553 - val_loss: 0.6854 - val_accuracy: 0.8333
# Epoch 37/50
# 77/77 [==============================] - 1s 12ms/step - loss: 0.1118 - accuracy: 0.9571 - val_loss: 0.7949 - val_accuracy: 0.8058
# Epoch 38/50
# 77/77 [==============================] - 1s 12ms/step - loss: 0.1182 - accuracy: 0.9558 - val_loss: 0.6861 - val_accuracy: 0.8591
# Epoch 39/50
# 77/77 [==============================] - 1s 12ms/step - loss: 0.1088 - accuracy: 0.9623 - val_loss: 0.5889 - val_accuracy: 0.8718
# Epoch 40/50
# 77/77 [==============================] - 1s 13ms/step - loss: 0.1082 - accuracy: 0.9585 - val_loss: 0.4894 - val_accuracy: 0.9218
# Epoch 41/50
# 77/77 [==============================] - 1s 12ms/step - loss: 0.0995 - accuracy: 0.9608 - val_loss: 0.5969 - val_accuracy: 0.8628
# Epoch 42/50
# 77/77 [==============================] - 1s 11ms/step - loss: 0.1025 - accuracy: 0.9604 - val_loss: 0.6397 - val_accuracy: 0.8558
# Epoch 43/50
# 77/77 [==============================] - 1s 12ms/step - loss: 0.1058 - accuracy: 0.9602 - val_loss: 0.5800 - val_accuracy: 0.8771
# Epoch 44/50
# 77/77 [==============================] - 1s 12ms/step - loss: 0.0989 - accuracy: 0.9635 - val_loss: 0.5932 - val_accuracy: 0.8460
# Epoch 45/50
# 77/77 [==============================] - 1s 12ms/step - loss: 0.0987 - accuracy: 0.9630 - val_loss: 0.6489 - val_accuracy: 0.8517
# Epoch 46/50
# 77/77 [==============================] - 1s 12ms/step - loss: 0.1006 - accuracy: 0.9620 - val_loss: 0.5329 - val_accuracy: 0.9037
# Epoch 47/50
# 77/77 [==============================] - 1s 12ms/step - loss: 0.1079 - accuracy: 0.9598 - val_loss: 0.7764 - val_accuracy: 0.8091
# Epoch 48/50
# 77/77 [==============================] - 1s 13ms/step - loss: 0.1002 - accuracy: 0.9645 - val_loss: 0.5306 - val_accuracy: 0.8992
# Epoch 49/50
# 77/77 [==============================] - 1s 12ms/step - loss: 0.0994 - accuracy: 0.9635 - val_loss: 0.6042 - val_accuracy: 0.8964
# Epoch 50/50
# 77/77 [==============================] - 1s 12ms/step - loss: 0.0870 - accuracy: 0.9662 - val_loss: 0.6024 - val_accuracy: 0.8705
# 77/77 [==============================] - 0s 4ms/step - loss: 0.6024 - accuracy: 0.8705

# %%
np.mean(accuracy)
# Out:
# 0.8965229272842408
